# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn import tree

# %%
print("Dataset: ")
import pandas as pd
dataset=pd.read_csv("C:\\Users\\dhruv\\OneDrive\\Documents\\Lungcancer.csv")
# Out:
# Dataset:

# %%
print(len(dataset))
# Out:
# 22

# %%
print(dataset.head())
# Out:
#      Name    Surname  Age  Smokes  AirQ  Alcohol  Result
# 0    John       Wick   35       3     5        4       1
# 1    John  Constants   27      20     2        5       1
# 2  Camela   Anderson   30       0     5        2       0
# 3    Alex    Tellers   28       0     8        1       0
# 4   Diego   Macadoma   68       4     5        6       1

# %%
scatter_matrix(dataset)
# Out:
# array([[<Axes: xlabel='Age', ylabel='Age'>,
#         <Axes: xlabel='Smokes', ylabel='Age'>,
#         <Axes: xlabel='AirQ', ylabel='Age'>,
#         <Axes: xlabel='Alcohol', ylabel='Age'>,
#         <Axes: xlabel='Result', ylabel='Age'>],
#        [<Axes: xlabel='Age', ylabel='Smokes'>,
#         <Axes: xlabel='Smokes', ylabel='Smokes'>,
#         <Axes: xlabel='AirQ', ylabel='Smokes'>,
#         <Axes: xlabel='Alcohol', ylabel='Smokes'>,
#         <Axes: xlabel='Result', ylabel='Smokes'>],
#        [<Axes: xlabel='Age', ylabel='AirQ'>,
#         <Axes: xlabel='Smokes', ylabel='AirQ'>,
#         <Axes: xlabel='AirQ', ylabel='AirQ'>,
#         <Axes: xlabel='Alcohol', ylabel='AirQ'>,
#         <Axes: xlabel='Result', ylabel='AirQ'>],
#        [<Axes: xlabel='Age', ylabel='Alcohol'>,
#         <Axes: xlabel='Smokes', ylabel='Alcohol'>,
#         <Axes: xlabel='AirQ', ylabel='Alcohol'>,
#         <Axes: xlabel='Alcohol', ylabel='Alcohol'>,
#         <Axes: xlabel='Result', ylabel='Alcohol'>],
#        [<Axes: xlabel='Age', ylabel='Result'>,
#         <Axes: xlabel='Smokes', ylabel='Result'>,
#         <Axes: xlabel='AirQ', ylabel='Result'>,
#         <Axes: xlabel='Alcohol', ylabel='Result'>,
#         <Axes: xlabel='Result', ylabel='Result'>]], dtype=object)

# %%
pyplot.show()

# %%
A = dataset[dataset.Result == 1]
B = dataset[dataset.Result == 0]

# %%
import matplotlib.pyplot as plt
plt.scatter(A.Age, A.Smokes, color="Black", label="1" , alpha=0.4)
plt.scatter(B.Age, B.Smokes, color="Blue", label="0" , alpha=0.4)
plt.xlabel("Age")
plt.ylabel("Smokes")
plt.legend()
plt.title("Smokes vs Age")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(A.Age, A.Alcohol, color="Black", label="1" , alpha=0.4)
plt.scatter(B.Age, B.Alcohol, color="Blue", label="0" , alpha=0.4)
plt.xlabel("Age")
plt.ylabel("Alcohol")
plt.legend()
plt.title("Alcohol vs Age")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(A.Smokes, A.Alcohol, color="Black", label="1" , alpha=0.4)
plt.scatter(B.Smokes, B.Alcohol, color="Blue", label="0" , alpha=0.4)
plt.xlabel("Smokes")
plt.ylabel("Alcohol")
plt.legend()
plt.title("Smokes vs Alcohol")
plt.show()

# %%
x = dataset.iloc[: ,3:5]
y = dataset.iloc[: ,6]
x_train, x_test, y_train, y_test = train_test_split(x , y, random_state=0, test_size=0.2)

# %%
sc_x = StandardScaler()
x_train = sc_x.fit_transform(x_train)

# %%
print('----------****Using KNN Algorithm****-----------')
import math
a=math.sqrt(len(y_train))
print(a)
# Out:
# ----------****Using KNN Algorithm****-----------
# 4.123105625617661

# %%
classifier = KNeighborsClassifier(n_neighbors=5 , p=2, metric='euclidean')
classifier.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean')

# %%
y_pred = classifier.predict(x_test)
print(y_pred)
# Out:
# [0 0 1 1 1]
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:413: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(

# %%
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix: ")
print(cm)
# Out:
# Confusion Matrix:
# [[1 1]
#  [1 2]]

# %%
print("In Confusion Matrix:----")
# Out:
# In Confusion Matrix:----

# %%
print("Position 1.1 shows the patients that  don't have Cancer, In this case = 1")
print("Position 1.2 shows the number of patients that  have high risk of  Cancer, In this case = 1")
print("Position 2.1 shows the Incorrecct Value, In this case = 1")
print("Position 2.2 shows the correct number of  patiaets that have Cancer, In this case = 2")
from sklearn.metrics import f1_score
print('F1 Score:' , (f1_score(y_test, y_pred))*100)
# Out:
# Position 1.1 shows the patients that  don't have Cancer, In this case = 1
# Position 1.2 shows the number of patients that  have high risk of  Cancer, In this case = 1
# Position 2.1 shows the Incorrecct Value, In this case = 1
# Position 2.2 shows the correct number of  patiaets that have Cancer, In this case = 2
# F1 Score: 66.66666666666666

# %%
print('ACCURACY:' , (accuracy_score(y_test, y_pred))*100)
# Out:
# ACCURACY: 60.0

# %%
print("------****Using Decision tree****-----")
from sklearn import tree
c = tree.DecisionTreeClassifier()
c.fit(x_train, y_train)
accu_train = np.sum(c.predict(x_train)==y_train)/float(y_train.size)
accu_test = np.sum(c.predict(x_test)==y_test)/float(y_test.size)
# Out:
# ------****Using Decision tree****-----
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:413: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(

# %%
print('Classification accuracy on train', (accu_train)*100)
print('Classification accuracy on test', (accu_test)*100)
# Out:
# Classification accuracy on train 94.11764705882352
# Classification accuracy on test 40.0
